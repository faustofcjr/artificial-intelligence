# %% [markdown]
# # Titanic - Machine Learning from Disaster
#
# ## Decision Tree Model

# %%
import pandas as pd
import numpy as np

import functions_classifier as func

from sklearn.tree import DecisionTreeClassifier

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Constants

# %%
PATH_PROCESSED_TRAIN_CSV = "../data/processed_train.csv"

# %% [markdown]
# ## Data Collection

# %%
train_df = pd.read_csv(PATH_PROCESSED_TRAIN_CSV)
train_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Ticket   Fare  Embarked  \
# 0           0       3    1  22.0      1      0     523   7.25         2
# 1           1       1    0  38.0      1      0     596  71.28         0
# 2           1       3    0  26.0      0      0     669   7.92         2
# 3           1       1    0  35.0      1      0      49  26.55         2
# 4           0       3    1  35.0      0      0     472   8.05         2
# ..        ...     ...  ...   ...    ...    ...     ...    ...       ...
# 886         0       2    1  27.0      0      0     101  13.00         2
# 887         1       1    0  19.0      0      0      14  30.00         2
# 888         0       3    0  29.0      1      2     675  11.72         2
# 889         1       1    1  26.0      0      0       8  30.00         0
# 890         0       3    1  32.0      0      0     466   7.75         1
#
#      Title  FamilyName  Kinship  Deck  Alone  AgeGroup
# 0        2          73        1     8      0         0
# 1        3         136        1     2      0         0
# 2        1         251        0     8      1         0
# 3        3         198        1     2      0         0
# 4        2          11        0     8      1         0
# ..     ...         ...      ...   ...    ...       ...
# 886      4         406        0     8      1         0
# 887      1         221        0     1      1         0
# 888      1         293        3     8      0         0
# 889      2          52        0     2      1         0
# 890      2         159        0     8      1         0
#
# [891 rows x 15 columns]

# %% [markdown]
# ## Feature Selection
#
# _Legend:_
#
# X: Feature Variables (or Independent Variables)
#
# y: Target Variables (or dependent Variables)

# %%
X = train_df.drop(["Survived"], axis=1)
y = train_df["Survived"]

# %% [markdown]
# ### Split dataset into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((668, 14), (668,))

# %%
X_test.shape, y_test.shape
# Out:
# ((223, 14), (223,))

# %% [markdown]
# ## Modeling

# %% [markdown]
# **Getting Best Hyperparameter Optimization**
#
# *Note: The execution of the code below may take a few minutes or hours.*
#
# *Uncomment and run it when you need to optimize hyperparameters.*

# %%
# space = dict()
# space['criterion'] = ["gini", "entropy"]
# space['splitter'] = ["best", "random"]
# space['max_depth'] = [n for n in range(50)]
# space['min_samples_split'] = [n for n in range(10)]
# space['min_samples_leaf'] = [n for n in range(10)]

# func.show_best_hyperparameter_optimization(
#     DecisionTreeClassifier(), 
#     space, 
#     X_train, 
#     y_train
# )

# %% [markdown]
# Best Score: 0.818920548771295
#
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 4, 'splitter': 'random'}

# %% [markdown]
# **Building, train and predict model**

# %%
decision_tree_classifier = DecisionTreeClassifier(
    criterion="entropy", 
    max_depth=6, 
    min_samples_split=4,
    splitter="random"
)
pipeline = make_pipeline(
    StandardScaler(),
    decision_tree_classifier
)

_ = pipeline.fit(X_train, y_train)

# %% [markdown]
# __Check the most relevant features for the training model__

# %%
func.get_feature_importances(decision_tree_classifier, X_train)
# Out:
#       Features  Relevance (%)
# 1          Sex             44
# 0       Pclass             18
# 2          Age              8
# 5       Ticket              6
# 11        Deck              6
# 3        SibSp              5
# 7     Embarked              4
# 9   FamilyName              4
# 8        Title              2
# 4        Parch              1
# 10     Kinship              1
# 13    AgeGroup              1
# 6         Fare              0
# 12       Alone              0

# %% [markdown]
# __Predict and show model result__

# %%
y_predict = pipeline.predict(X_test)
func.show_model_result(pipeline, X, y, y_test, y_predict)
# Out:
# Computing cross-validated metrics
# ----------------------------------------------------------------------
# Scores: [0.83240223 0.80898876 0.80337079 0.79775281 0.86516854]
# Mean = 0.82 / Standard Deviation = 0.02
#
# Confunsion Matrix
# ----------------------------------------------------------------------
# [[118  16]
#  [ 29  60]]
#
# Classification Report
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       134
#            1       0.79      0.67      0.73        89
#
#     accuracy                           0.80       223
#    macro avg       0.80      0.78      0.78       223
# weighted avg       0.80      0.80      0.79       223
#
# ----------------------------------------------------------------------
# Accuracy: 0.80
# Precicion: 0.80
# Sensitivity aka Recall: 0.80
# F1-Score: 0.79

# %% [markdown]
# #### Display Confusion Matrix

# %%
func.display_confusion_matrix(pipeline, y_test, y_predict)

# %% [markdown]
# #### Show Curve ROC

# %%
func.show_curve_roc(pipeline, X_test, y_test, y_predict)
# Out:
# ----------------------------------------------------------------------
# AUC-Area Under the ROC Curve: 0.78
# ----------------------------------------------------------------------

# %% [markdown]
# __Compare Ground Truth vs Prediction Model__

# %%
func.get_error_prediction(X_test, y_test, y_predict)
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Ticket   Fare  Embarked  Title  \
# 709       3    1  29.0      1      1     189   7.62         0      0
# 208       3    0  16.0      0      0     445   7.75         1      1
# 621       1    1  42.0      1      0      56  52.55         2      2
# 447       1    1  34.0      0      0      45  26.55         2      2
# 192       3    0  19.0      1      0     406   7.85         2      1
# 673       2    1  31.0      0      0     145  13.00         2      2
# 63        3    1   4.0      3      2     337   4.65         2      0
# 396       3    0  31.0      0      0     414   7.85         2      1
# 235       3    0  29.0      0      0     677   7.55         2      1
# 204       3    1  18.0      0      0     530   8.05         2      2
# 23        1    1  28.0      0      0      42  35.50         2      2
# 44        3    0  19.0      0      0     282   7.88         1      1
# 772       2    0  57.0      0      0     619   5.25         2      3
# 312       2    0  26.0      1      1     167  26.00         2      3
# 889       1    1  26.0      0      0       8  30.00         0      2
# 767       3    0  30.5      0      0     436   7.75         1      1
# 357       2    0  38.0      0      0     131  13.00         2      1
# 254       3    0  41.0      0      2     458  10.11         2      3
# 165       3    1   9.0      0      2     423   6.84         2      0
# 712       1    1  48.0      1      0      99  26.00         2      2
# 338       3    1  45.0      0      0     510   8.05         2      2
# 286       3    1  30.0      0      0     308   9.50         2      2
# 209       1    1  40.0      0      0      17  31.00         0      2
